# %%
from utils import *
from Siamese_Data import ESC_data

# %%
train_dataset = ESC_data()

# %%
audio1, audio2, pair_label = train_dataset[1]

# %%
plt.figure(figsize=(20, 4))
plt.subplot(121)
plt.imshow(audio1[0],aspect='auto')
plt.title('Audio 1')

plt.subplot(122)
plt.imshow(audio2[0],aspect='auto')
plt.title('Audio 2')
plt.tight_layout()
plt.show()

# %%
from ipywidgets import interact
@interact(index=(0, len(train_dataset)-1))
def show_sample(index=0):
    audio1, audio2, pair_label = train_dataset[index]
    plt.figure(figsize=(20, 4))
    plt.subplot(121)
    plt.imshow(audio1[0],aspect='auto')
    plt.title('Audio 1')

    plt.subplot(122)
    plt.imshow(audio2[0],aspect='auto')
    plt.title('Audio 2')
    plt.tight_layout()
    plt.show()
    print(pair_label)
# Out:
# interactive(children=(IntSlider(value=0, description='index', max=1199), Output()), _dom_classes=('widget-inte…
